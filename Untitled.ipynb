# %%
# !openneuro-py download --dataset ds002424
# Out:
# ðŸ‘‹ Hello! This is openneuro-py 2023.1.0. Great to see you! ðŸ¤—
#
#    ðŸ‘‰ Please report problems ðŸ¤¯ and bugs ðŸª² at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# ðŸŒ� Preparing to download ds002424 â€¦
# ðŸ“¥ Retrieving up to 21 files (5 concurrent downloads).
# âœ… Finished downloading ds002424.
#
# ðŸ§  Please enjoy your brains.
# \U0001f4c1 Traversing directories for ds002424 : 0 entities [00:00, ? entities/s]
# \U0001f4c1 Traversing directories for ds002424 : 21 entities [00:22,  1.08s/ entities]
#
# CHANGES: 0.00B [00:00, ?B/s]
#
#
# README: 0.00B [00:00, ?B/s]
#
#
# dataset_description.json: 0.00B [00:00, ?B/s]
#
#
# participants.tsv: 0.00B [00:00, ?B/s]
#
#
# participants.json: 0.00B [00:00, ?B/s]
#
#
# task-SLD_bold.json: 0.00B [00:00, ?B/s]
#
#
# task-SLD_events.json: 0.00B [00:00, ?B/s]
#
#
# task-SLI_bold.json: 0.00B [00:00, ?B/s]
#
#
# task-SLI_events.json: 0.00B [00:00, ?B/s]
#
#
# task-SSD_bold.json: 0.00B [00:00, ?B/s]
#
#
# ...
